# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(np.random.randint(0, 100, size=(7, 5)), 
                  columns=["x1", "x2", "x3", "x4", "x5"])
df
# Out:
#    x1  x2  x3  x4  x5
# 0  21   8  10  30  11
# 1  31  84  64   0  48
# 2  78  89  93  43  31
# 3  77  43   5  68   2
# 4  89  87  70  88  40
# 5  97   6  95  48  47
# 6  81   7  84  18  92

# %%
df.count()
# Out:
# x1    7
# x2    7
# x3    7
# x4    7
# x5    7
# dtype: int64

# %%
df.count(axis="columns")
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# 6    5
# dtype: int64

# %%
df.idxmax()
# Out:
# x1    5
# x2    2
# x3    5
# x4    4
# x5    6
# dtype: int64

# %%
df.idxmax(axis="columns")
# Out:
# 0    x4
# 1    x2
# 2    x3
# 3    x1
# 4    x1
# 5    x1
# 6    x5
# dtype: object

# %%
df
# Out:
#    x1  x2  x3  x4  x5
# 0  21   8  10  30  11
# 1  31  84  64   0  48
# 2  78  89  93  43  31
# 3  77  43   5  68   2
# 4  89  87  70  88  40
# 5  97   6  95  48  47
# 6  81   7  84  18  92

# %%
df.loc[0:2, ["x4"]]
# Out:
#    x4
# 0  30
# 1   0
# 2  43

# %%
df.loc[(df.x4 <50), ["x4"]]
# Out:
#    x4
# 0  30
# 1   0
# 2  43
# 5  48
# 6  18

# %%
df
# Out:
#    x1  x2  x3  x4  x5
# 0  21   8  10  30  11
# 1  31  84  64   0  48
# 2  78  89  93  43  31
# 3  77  43   5  68   2
# 4  89  87  70  88  40
# 5  97   6  95  48  47
# 6  81   7  84  18  92

# %%
df.loc[4].sum()
# Out:
# 374

# %%
df.loc[3:4]
# Out:
#    x1  x2  x3  x4  x5
# 3  77  43   5  68   2
# 4  89  87  70  88  40

# %%
df[["x4","x3"]].sum()
# Out:
# x4    295
# x3    421
# dtype: int64

# %%
data = {'Company':['GOOG', 'GOOG', 'MSFT', 'MSFT', 'GOOG', 'MSFT', 'GOOG', 'MSFT'],
        'Department':['HR', 'IT', 'IT', 'HR', 'HR', 'IT', 'IT', 'HR'],
        'Person':['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah', 'Tom', 'Terry'],
        'Age':[30, 28, 35, 40, 42, 25, 32, 48],
        'Sales':[200, 120, 340, 124, 243, 350, 180, 220]}

# %%
df = pd.DataFrame(data=data)
df
# Out:
#   Company Department   Person  Age  Sales
# 0    GOOG         HR      Sam   30    200
# 1    GOOG         IT  Charlie   28    120
# 2    MSFT         IT      Amy   35    340
# 3    MSFT         HR  Vanessa   40    124
# 4    GOOG         HR     Carl   42    243
# 5    MSFT         IT    Sarah   25    350
# 6    GOOG         IT      Tom   32    180
# 7    MSFT         HR    Terry   48    220

# %%
df.groupby(["Company"]).mean()
# Out:
#           Age   Sales
# Company
# GOOG     33.0  185.75
# MSFT     37.0  258.50

# %%
df.groupby(["Department"]).mean()
# Out:
#              Age   Sales
# Department
# HR          40.0  196.75
# IT          30.0  247.50

# %%
df.groupby("Company")[["Sales"]].mean()
# Out:
#           Sales
# Company
# GOOG     185.75
# MSFT     258.50

# %%
df.groupby(["Company", "Department"]).mean()
# Out:
#                      Age  Sales
# Company Department
# GOOG    HR          36.0  221.5
#         IT          30.0  150.0
# MSFT    HR          44.0  172.0
#         IT          30.0  345.0

# %%
df.groupby(["Company", "Department"])[["Sales"]].mean()
# Out:
#                     Sales
# Company Department
# GOOG    HR          221.5
#         IT          150.0
# MSFT    HR          172.0
#         IT          345.0

# %%
df = pd.DataFrame({'groups': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
                   'var1': [10, 23, 33, 22, 11, 99, 76, 84, 45],
                   'var2': [100, 253, 333, 262, 111, 969, 405, 578, 760]})
df
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df.agg([sum, max])
# Out:
#         groups  var1  var2
# sum  ABCABCABC   403  3771
# max          C    99   969

# %%
df[["var1", "var2"]].agg([sum,max])
# Out:
#      var1  var2
# sum   403  3771
# max    99   969

# %%
df.agg({"var1": sum, "var2": max})
# Out:
# var1    403
# var2    969
# dtype: int64

# %%
df.agg({"var1": [min,max], "var2": [sum,max]})
# Out:
#      var1    var2
# min  10.0     NaN
# max  99.0   969.0
# sum   NaN  3771.0

# %%
df
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df.groupby("groups").agg({"var1": [min,max], "var2": sum})
# Out:
#        var1      var2
#         min max   sum
# groups
# A        10  76   767
# B        11  84   942
# C        33  99  2062

# %%
df.groupby("groups").agg([np.min])
# Out:
#        var1 var2
#        amin amin
# groups
# A        10  100
# B        11  111
# C        33  333

# %%
df2 = pd.DataFrame({'groups': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
                   'var1': [10, 23, 33, 22, 11, 99, 76, 84, 45],
                   'var2': [100, 253, 333, 262, 111, 969, 405, 578, 760]})
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.groupby(["groups"]).agg(sum)
# Out:
#         var1  var2
# groups
# A        108   767
# B        118   942
# C        177  2062

# %%
df2.groupby("groups").agg([sum,max])
# Out:
#        var1      var2
#         sum max   sum  max
# groups
# A       108  76   767  405
# B       118  84   942  578
# C       177  99  2062  969

# %%
df2[["var1"]].agg([sum])
# Out:
#      var1
# sum   403

# %%
df2[["var1", "var2"]].agg([sum,max])
# Out:
#      var1  var2
# sum   403  3771
# max    99   969

# %%
df2.groupby("groups")[["var1"]].agg(sum)
# Out:
#         var1
# groups
# A        108
# B        118
# C        177

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.filter(items=["var1","var2"])
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df2.filter(items=["groups","var2"])
# Out:
#   groups  var2
# 0      A   100
# 1      B   253
# 2      C   333
# 3      A   262
# 4      B   111
# 5      C   969
# 6      A   405
# 7      B   578
# 8      C   760

# %%
df2.filter(regex = "^va", axis = 1)
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df2.filter(like = "va", axis = 1)
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df2.filter(like = "1", axis = 1)
# Out:
#    var1
# 0    10
# 1    23
# 2    33
# 3    22
# 4    11
# 5    99
# 6    76
# 7    84
# 8    45

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
def filter_function(x):
    return x["var1"].mean() >39

# %%
df2.groupby("groups").filter(filter_function)
# Out:
#   groups  var1  var2
# 1      B    23   253
# 2      C    33   333
# 4      B    11   111
# 5      C    99   969
# 7      B    84   578
# 8      C    45   760

# %%
df2.groupby("groups")[["var2"]].sum()
# Out:
#         var2
# groups
# A        767
# B        942
# C       2062

# %%
df2.filter(items=["var1"]).sum()
# Out:
# var1    403
# dtype: int64

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.groupby("groups").filter(lambda x: x["var2"].sum() >800)
# Out:
#   groups  var1  var2
# 1      B    23   253
# 2      C    33   333
# 4      B    11   111
# 5      C    99   969
# 7      B    84   578
# 8      C    45   760

# %%
df2.groupby("groups").sum()
# Out:
#         var1  var2
# groups
# A        108   767
# B        118   942
# C        177  2062

# %%
df_num = df2.iloc[:,1:3]
df_num
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.transform(lambda x: x+10)
# Out:
#    var1  var2
# 0    20   110
# 1    33   263
# 2    43   343
# 3    32   272
# 4    21   121
# 5   109   979
# 6    86   415
# 7    94   588
# 8    55   770

# %%
df_num.transform([np.sqrt,np.exp])
# Out:
#        var1                     var2
#        sqrt           exp       sqrt            exp
# 0  3.162278  2.202647e+04  10.000000   2.688117e+43
# 1  4.795832  9.744803e+09  15.905974  7.524955e+109
# 2  5.744563  2.146436e+14  18.248288  4.169294e+144
# 3  4.690416  3.584913e+09  16.186414  6.097534e+113
# 4  3.316625  5.987414e+04  10.535654   1.609487e+48
# 5  9.949874  9.889030e+42  31.128765            inf
# 6  8.717798  1.014800e+33  20.124612  7.749348e+175
# 7  9.165151  3.025077e+36  24.041631  1.052472e+251
# 8  6.708204  3.493427e+19  27.568098            inf

# %%
df2["var1_mean_trns"] = df2.groupby("groups")["var1"].transform("mean")
df2
# Out:
#   groups  var1  var2  var1_mean_trs  var1_mean_trns
# 0      A    10   100            NaN       36.000000
# 1      B    23   253            NaN       39.333333
# 2      C    33   333            NaN       59.000000
# 3      A    22   262            NaN       36.000000
# 4      B    11   111            NaN       39.333333
# 5      C    99   969            NaN       59.000000
# 6      A    76   405            NaN       36.000000
# 7      B    84   578            NaN       39.333333
# 8      C    45   760            NaN       59.000000

# %%
df3 = pd.DataFrame({'col1':[1, 2, 3, 4],
                    'col2':[444, 555, 666, 444],
                    'col3':['abc', 'def', 'ghi', 'xyz']})
df3
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def squared(x):
    return x**2

# %%
df3["col1"].apply(squared)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
x = 9
np.sqrt(x)
# Out:
# 3.0

# %%
df3['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df3["col3"].apply(lambda x: x[0]*3)
# Out:
# 0    aaa
# 1    ddd
# 2    ggg
# 3    xxx
# Name: col3, dtype: object

# %%
df3["col2"].apply(lambda x: "high" if  x >500 else "low")
# Out:
# 0     low
# 1    high
# 2    high
# 3     low
# Name: col2, dtype: object

# %%
df2 = df2[["groups", "var1", "var2"]]

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.apply(np.sum)
# Out:
# groups    ABCABCABC
# var1            403
# var2           3771
# dtype: object

# %%
df_num
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.apply([np.sum])
# Out:
#      var1  var2
# sum   403  3771

# %%
df_num.applymap(np.sum)
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.apply([np.sum], axis=1)
# Out:
#     sum
# 0   110
# 1   276
# 2   366
# 3   284
# 4   122
# 5  1068
# 6   481
# 7   662
# 8   805

# %%
df_num
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.applymap(lambda x: x*5)
# Out:
#    var1  var2
# 0    50   500
# 1   115  1265
# 2   165  1665
# 3   110  1310
# 4    55   555
# 5   495  4845
# 6   380  2025
# 7   420  2890
# 8   225  3800

# %%
df_num["var1"]*5
# Out:
# 0     50
# 1    115
# 2    165
# 3    110
# 4     55
# 5    495
# 6    380
# 7    420
# 8    225
# Name: var1, dtype: int64

# %%
df3
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df3.col1.map({1 : "A",  2: "B"})
# Out:
# 0      A
# 1      B
# 2    NaN
# 3    NaN
# Name: col1, dtype: object

# %%
s = pd.Series(["fox", "cow", np.nan, "dog"])
s
# Out:
# 0    fox
# 1    cow
# 2    NaN
# 3    dog
# dtype: object

# %%
s.map("it is a {}".format)
# Out:
# 0    it is a fox
# 1    it is a cow
# 2    it is a nan
# 3    it is a dog
# dtype: object

# %%
df5 = pd.DataFrame({'A': [1,2,3], 'B': [10,20,30] })
df5
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df5.apply(lambda x: x**2)
# Out:
#    A    B
# 0  1  100
# 1  4  400
# 2  9  900

# %%
df5.transform(lambda x: x*3)
# Out:
#    A   B
# 0  3  30
# 1  6  60
# 2  9  90

# %%
df5.apply(lambda x: x[0]*3, axis=1)
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
data = {'gender':['male', 'female', 'female', 'male', 'female', 'male'],
        'sport':['tennis', 'tennis', 'basketball', 'football', 'voleyball', 'basketball'],
        'status':["professional","professional","professional","amateur","amateur","amateur"],
        'age':[20, 24, 26, 23, 22, 21],
        'height':[185, 172, 175, 178, 182, 196],
        'weight':[83, 58, 62, 80, 65, 90]}

df7 = pd.DataFrame(data)

df7
# Out:
#    gender       sport        status  age  height  weight
# 0    male      tennis  professional   20     185      83
# 1  female      tennis  professional   24     172      58
# 2  female  basketball  professional   26     175      62
# 3    male    football       amateur   23     178      80
# 4  female   voleyball       amateur   22     182      65
# 5    male  basketball       amateur   21     196      90
